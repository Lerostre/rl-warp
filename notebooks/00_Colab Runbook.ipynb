# %%
# !git clone https://github.com/Lerostre/rl-warp.git
# %cd rl-warp
# !git switch master
# Out:
# Cloning into 'rl-warp'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 240 (delta 79), reused 161 (delta 43), pack-reused 0
# Receiving objects: 100% (240/240), 5.51 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# /content/rl-warp
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Switched to a new branch 'master'

# %%
VENV_PATH = "content/rl-warp/.venv/lib/python3.10/site-packages"

# %%
# !pip install -q poetry
# !poetry config virtualenvs.in-project true
# !poetry lock --no-update
# !poetry install
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 80%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 59%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 30%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 30%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 70%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 30%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 37%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 80%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 70%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 15%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 80%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 70%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 70%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 90%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 70%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 80%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 90%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 80%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 17%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 90%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 80%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 80%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 99%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 80%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 88%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 47%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0): Installing...
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0): Pending...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0): Pending...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0): Pending...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0): Pending...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 90%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0): Pending...
#   - Installing six (1.16.0): Downloading... 0%
#   - Installing six (1.16.0): Downloading... 100%
#   - Installing six (1.16.0): Installing...
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Pending...
#   - Installing sympy (1.13.1): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 99%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 90%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 0%
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 18%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 99%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 90%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 0%
#   - Installing sympy (1.13.1): Downloading... 10%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 10%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 91%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 50%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 10%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 10%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 51%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 10%
#   - Installing sympy (1.13.1): Downloading... 20%
#   - Installing sympy (1.13.1): Downloading... 30%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 51%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 30%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 92%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 51%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 30%
#   - Installing sympy (1.13.1): Downloading... 40%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 40%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 52%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 40%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 52%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 40%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 93%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 52%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 40%
#   - Installing sympy (1.13.1): Downloading... 50%
#   - Installing sympy (1.13.1): Downloading... 60%
#   - Installing sympy (1.13.1): Downloading... 90%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 90%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 90%
#   - Installing sympy (1.13.1): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 93%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 100%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 93%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 100%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 97%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Downloading... 100%
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 97%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 19%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 97%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 97%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 20%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 97%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 54%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4): Pending...
#   - Installing tqdm (4.66.4): Downloading... 0%
#   - Installing tqdm (4.66.4): Downloading... 100%
#   - Installing tqdm (4.66.4): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Pending...
#   - Installing triton (3.0.0): Downloading... 0%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 0%
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 21%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 59%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 0%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 0%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 66%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 0%
#   - Installing triton (3.0.0): Downloading... 6%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 6%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 70%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 6%
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 70%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 23%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Downloading... 100%
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 70%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 77%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 80%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 80%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 80%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 10%
# Installing /content/rl-warp/.venv/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing triton (3.0.0): Downloading... 16%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 80%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 16%
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 25%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Downloading... 100%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 80%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 16%
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 86%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 86%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 86%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1): Installing...
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
# Installing /content/rl-warp/.venv/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 86%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 27%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 86%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing typing-extensions (4.12.2): Downloading... 0%
#   - Installing typing-extensions (4.12.2): Downloading... 100%
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4): Pending...
#   - Installing yarl (1.9.4): Downloading... 0%
#   - Installing yarl (1.9.4): Downloading... 100%
#   - Installing yarl (1.9.4): Installing...
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 90%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 20%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 26%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 30%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 90%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 30%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 29%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 90%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 30%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 30%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 99%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 30%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 35%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 99%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 35%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 31%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 99%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 35%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 36%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 99%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 36%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 32%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 99%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 36%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 37%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 38%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 40%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 40%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 40%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 40%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 33%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 40%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 48%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 50%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 50%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 35%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 50%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 58%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 60%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 60%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 38%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 60%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 60%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 40%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Downloading... 100%
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 60%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 67%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 67%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-nccl-cu12 (2.20.5): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 67%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
# Installing /content/rl-warp/.venv/lib/python3.10/site-packages/nvidia/__init__.py over existing file
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing triton (3.0.0): Downloading... 70%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
#   - Installing packaging (24.1)
#   - Installing pyyaml (6.0.1)
#   - Installing requests (2.32.3)
#   - Updating setuptools (70.1.0 -> 72.1.0)
#   - Installing six (1.16.0)
#   - Installing sympy (1.13.1)
#   - Installing tqdm (4.66.4)
#   - Installing triton (3.0.0): Downloading... 70%
#   - Installing typing-extensions (4.12.2)
#   - Installing yarl (1.9.4)
#   - Installing nvidia-cudnn-cu12 (9.1.0.70): Downloading... 42%
#   - Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   - Installing nvidia-curand-cu12 (10.3.2.106)
#   - Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   - Installing nvidia-nccl-cu12 (2.20.5): Installing...
#   - Installing nvidia-nvtx-cu12 (12.1.105)
# ...
#   - Installing nltk (3.8.1): Downloading... 60%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0): Installing...
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Downloading... 60%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Pending...
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing nltk (3.8.1): Downloading... 70%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Downloading... 70%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Downloading... 70%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Pending...
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Downloading... 70%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Pending...
#   - Installing bokeh (3.5.1): Downloading... 20%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Downloading... 70%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Pending...
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Pending...
#   - Installing nltk (3.8.1): Downloading... 100%
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Pending...
#   - Installing trl (0.9.6): Downloading... 0%
#   - Installing trl (0.9.6): Downloading... 100%
#   - Installing trl (0.9.6): Installing...
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing bokeh (3.5.1): Downloading... 40%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6): Installing...
#   - Installing wandb (0.17.5): Pending...
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing bokeh (3.5.1): Downloading... 60%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing polars (1.4.0): Downloading... 10%
#   - Installing scipy (1.14.0): Downloading... 0%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 0%
#   - Installing wandb (0.17.5): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 20%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 20%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 10%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 20%
#   - Installing bokeh (3.5.1): Downloading... 80%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 10%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 20%
#   - Installing wandb (0.17.5): Downloading... 40%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 10%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 40%
#   - Installing bokeh (3.5.1): Downloading... 100%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 10%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 40%
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing polars (1.4.0): Downloading... 20%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 20%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing bokeh (3.5.1): Installing...
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1): Installing...
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 20%
#   - Installing scipy (1.14.0): Downloading... 10%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing scipy (1.14.0): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 60%
#   - Installing wandb (0.17.5): Downloading... 90%
#   - Installing scipy (1.14.0): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 90%
#   - Installing polars (1.4.0): Downloading... 30%
#   - Installing scipy (1.14.0): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 90%
#   - Installing wandb (0.17.5): Downloading... 100%
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 30%
#   - Installing scipy (1.14.0): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 100%
#   - Installing nltk (3.8.1)
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Downloading... 30%
#   - Installing scipy (1.14.0): Downloading... 20%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Downloading... 100%
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 30%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 30%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 40%
#   - Installing scipy (1.14.0): Downloading... 30%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 30%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 50%
#   - Installing scipy (1.14.0): Downloading... 30%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 40%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 40%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 60%
#   - Installing scipy (1.14.0): Downloading... 40%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 50%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 50%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 70%
#   - Installing scipy (1.14.0): Downloading... 50%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 80%
#   - Installing scipy (1.14.0): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 90%
#   - Installing scipy (1.14.0): Downloading... 60%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 70%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 80%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 80%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing polars (1.4.0): Downloading... 100%
#   - Installing scipy (1.14.0): Downloading... 80%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing scipy (1.14.0): Downloading... 90%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5): Installing...
#   - Installing wandb (0.17.5)
#   - Installing scipy (1.14.0): Downloading... 90%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing polars (1.4.0): Installing...
#   - Installing scipy (1.14.0): Downloading... 90%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing scipy (1.14.0): Downloading... 100%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1)
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Installing...
#   - Installing scipy (1.14.0): Downloading... 100%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing bokeh (3.5.1)
#   - Installing hydra-core (1.3.2)
#   - Installing ipykernel (6.29.5)
#   - Installing ipywidgets (8.1.3)
#   - Installing lightning-bolts (0.7.0)
#   - Installing loguru (0.7.2)
#   - Installing nltk (3.8.1)
#   - Installing peft (0.12.0)
#   - Installing polars (1.4.0): Installing...
#   - Installing scipy (1.14.0): Downloading... 100%
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing scipy (1.14.0): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing scipy (1.14.0): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing polars (1.4.0)
#   - Installing scipy (1.14.0): Installing...
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
#   - Installing scipy (1.14.0)
#   - Installing trl (0.9.6)
#   - Installing wandb (0.17.5)
# Warning: The file chosen for install of polars 1.4.0 (polars-1.4.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl) is yanked. Reason for being yanked: regression
#
# Installing the current project: rl-warp (0.1.0)
# Warning: The current project could not be installed: No file/folder found for package rl-warp
# If you do not want to install the current project use --no-root.
# If you want to use Poetry only for dependency management but not for packaging, you can disable package mode by setting package-mode = false in your pyproject.toml file.
# In a future version of Poetry this warning will become an error!

# %%
from huggingface_hub import login

login()
